# %% [markdown]
# # Obtain the Repo

# %%
# !git clone https://github.com/chansurgeplus/direct-preference-optimization.git
# Out:
# Cloning into 'direct-preference-optimization'...
# remote: Enumerating objects: 391, done.
# remote: Counting objects: 100% (391/391), done.
# remote: Compressing objects: 100% (155/155), done.
# remote: Total 391 (delta 261), reused 345 (delta 234), pack-reused 0
# Receiving objects: 100% (391/391), 78.69 KiB | 516.00 KiB/s, done.
# Resolving deltas: 100% (261/261), done.

# %% [markdown]
# # Run

# %%
import os

# %%
os.chdir("direct-preference-optimization")

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-0hq07ola
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-0hq07ola
#   Resolved https://github.com/huggingface/transformers to commit eb644980eb7bd7ed5bc46d47df94a4c87ae31bcf
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.2/152.2 kB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 49.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 66.5 MB/s eta 0:00:0000:01:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 6.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 34.4 MB/s eta 0:00:00
# ...

# %%
# !pip install accelerate --upgrade
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 15.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.21.0
#     Uninstalling accelerate-0.21.0:
#       Successfully uninstalled accelerate-0.21.0
# ...

# %%
# !pip install transformers -U

# %%
# !python -u train.py model=openbezoar-hh-rlhf-sft datasets=[hh] loss=dpo loss.beta=0.1 exp_name=DPO_DPO_OpenLLaMa_3b_v2 gradient_accumulation_steps=2 batch_size=4 eval_batch_size=16 trainer=BasicTrainer sample_during_eval=false eval_every=1000 save_every=5000 max_length=2048 max_prompt_length=1024 s3.enabled=false
